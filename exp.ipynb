# %%
# !pip install torch_geometric > /dev/null 2>&1
# !pip install zarr==2.13.0 > /dev/null 2>&1
# !pip install numcodecs==0.13.1 > /dev/null 2>&1

# %%
# !gdown https://drive.google.com/uc?id=13kcgRFLwtXyMRTqVxciqGsmRhkqI0L1v
# !gdown https://drive.google.com/uc?id=1GSepR_rSd6fYyx9TwxLYVEg5ydvKGEQ_
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=13kcgRFLwtXyMRTqVxciqGsmRhkqI0L1v
# From (redirected): https://drive.google.com/uc?id=13kcgRFLwtXyMRTqVxciqGsmRhkqI0L1v&confirm=t&uuid=a3a37fc8-9705-4fd7-a6cc-e89384a7a58d
# To: /content/ns_opt_final_big.zarr.zip
# 100% 392M/392M [00:07<00:00, 49.8MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1GSepR_rSd6fYyx9TwxLYVEg5ydvKGEQ_
# From (redirected): https://drive.google.com/uc?id=1GSepR_rSd6fYyx9TwxLYVEg5ydvKGEQ_&confirm=t&uuid=998b315f-cb2f-4ac5-9c2c-8363e2c2c018
# To: /content/ns_opt_final_test_big.zarr.zip
# 100% 200M/200M [00:03<00:00, 65.2MB/s]

# %%
# !gdown https://drive.google.com/uc?id=1XPMw88UwxvY28xmLNMkoKUxMTi4W-uw6
# !gdown https://drive.google.com/uc?id=1S3pg2oMJVnycAfCPfT_z8AJZariti_VZ
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1XPMw88UwxvY28xmLNMkoKUxMTi4W-uw6
# From (redirected): https://drive.google.com/uc?id=1XPMw88UwxvY28xmLNMkoKUxMTi4W-uw6&confirm=t&uuid=28ee7246-cfac-4e81-8a23-8a5928ca2378
# To: /content/opt_final_big.zarr.zip
# 100% 392M/392M [00:04<00:00, 79.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1S3pg2oMJVnycAfCPfT_z8AJZariti_VZ
# From (redirected): https://drive.google.com/uc?id=1S3pg2oMJVnycAfCPfT_z8AJZariti_VZ&confirm=t&uuid=ee93c117-4765-4bfc-803d-8c673be38dc9
# To: /content/opt_final_test_big.zarr.zip
# 100% 200M/200M [00:02<00:00, 79.8MB/s]

# %%
# !gdown https://drive.google.com/uc?id=1wdi8x7HpPeVcKPbEhxIWHPzulgKeGqfc
# !gdown https://drive.google.com/uc?id=1bD3DwGZY8M2qunlr79XRvgkWlplJ7utI
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1wdi8x7HpPeVcKPbEhxIWHPzulgKeGqfc
# From (redirected): https://drive.google.com/uc?id=1wdi8x7HpPeVcKPbEhxIWHPzulgKeGqfc&confirm=t&uuid=9e0c8da6-6101-48e7-88c4-40f2f0e5975b
# To: /content/final_big.zarr.zip
# 100% 366M/366M [00:04<00:00, 77.2MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1bD3DwGZY8M2qunlr79XRvgkWlplJ7utI
# From (redirected): https://drive.google.com/uc?id=1bD3DwGZY8M2qunlr79XRvgkWlplJ7utI&confirm=t&uuid=212e2e1d-a9c3-403e-b209-5ee25e285bb1
# To: /content/final_test_big.zarr.zip
# 100% 188M/188M [00:03<00:00, 60.7MB/s]

# %%
# !gdown https://drive.google.com/uc?id=19BG2sSB0juRfTpGsaTOw_kbs7X0gDQ5Q
# !gdown https://drive.google.com/uc?id=1xPxolEEcfQjVCurztYaJ3BzTMpKreu7Y
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=19BG2sSB0juRfTpGsaTOw_kbs7X0gDQ5Q
# From (redirected): https://drive.google.com/uc?id=19BG2sSB0juRfTpGsaTOw_kbs7X0gDQ5Q&confirm=t&uuid=4cf114b2-4176-4418-93d8-3ded28157072
# To: /content/coo_optim_2_big_test.zarr.zip
# 100% 767M/767M [00:11<00:00, 68.8MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1xPxolEEcfQjVCurztYaJ3BzTMpKreu7Y
# From (redirected): https://drive.google.com/uc?id=1xPxolEEcfQjVCurztYaJ3BzTMpKreu7Y&confirm=t&uuid=71b9b8ae-903f-4a1b-90ae-1ca0a8807f94
# To: /content/coo_optim_2_big.zarr.zip
# 100% 1.51G/1.51G [00:26<00:00, 57.8MB/s]

# %%
# !gdown https://drive.google.com/uc?id=1wis7wK9ySedhRTLHUYCBtY7Q6UD1W7xC
# !gdown https://drive.google.com/uc?id=1zMal_EuB5Rq2tsi62yABKVzu1i3D-KYi
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1wis7wK9ySedhRTLHUYCBtY7Q6UD1W7xC
# From (redirected): https://drive.google.com/uc?id=1wis7wK9ySedhRTLHUYCBtY7Q6UD1W7xC&confirm=t&uuid=3aa00d7a-437b-43aa-bd27-93ca3ce594c7
# To: /content/coo_optim_2.zarr.zip
# 100% 197M/197M [00:05<00:00, 36.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1zMal_EuB5Rq2tsi62yABKVzu1i3D-KYi
# From (redirected): https://drive.google.com/uc?id=1zMal_EuB5Rq2tsi62yABKVzu1i3D-KYi&confirm=t&uuid=68c15d6c-27ff-4485-be0d-e25c6247df04
# To: /content/coo_optim_2_test.zarr.zip
# 100% 184M/184M [00:03<00:00, 59.9MB/s]

# %%
# !unzip -q /content/ns_opt_final_big.zarr.zip -d data
# !unzip -q /content/ns_opt_final_test_big.zarr.zip -d data

# %%
# !unzip -q /content/opt_final_big.zarr.zip -d data
# !unzip -q /content/opt_final_test_big.zarr.zip -d data

# %%
# !unzip -q /content/final_big.zarr.zip -d data
# !unzip -q /content/final_test_big.zarr.zip -d data

# %%
# !unzip -q /content/coo_optim_2.zarr.zip -d data
# !unzip -q /content/coo_optim_2_test.zarr.zip -d data

# %%
# !rm -rf data

# %%
# !unzip -q /content/coo_optim_2_big.zarr.zip -d data
# !unzip -q /content/coo_optim_2_big_test.zarr.zip -d data

# %%
import torch
import torch.nn as nn
import torch_geometric.nn as gnn
import torch.optim as optim
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from tqdm.auto import tqdm
import seaborn as sns

import torch.multiprocessing

torch.multiprocessing.set_sharing_strategy("file_system")

from dataset import SEEDIVDataset, AsyncBatchLoader

# Установка устройства
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

sns.set(font_scale=1.4, style="whitegrid")
figure_format = "retina"
# Out:
# cuda

# %%
class DCGRU(nn.Module):
    def __init__(self, input_dim, hiden_dim, K, normalization="sym"):
        super().__init__()
        self.input_dim = input_dim
        self.hiden_dim = hiden_dim
        self.K = K

        self.reset_conv = gnn.ChebConv(
            input_dim + hiden_dim, hiden_dim, K, normalization
        ).to(device)
        self.update_conv = gnn.ChebConv(
            input_dim + hiden_dim, hiden_dim, K, normalization
        ).to(device)
        self.mem_conv = gnn.ChebConv(
            input_dim + hiden_dim, hiden_dim, K, normalization
        ).to(device)

        self.sigmoid = nn.Sigmoid()
        self.tanh = nn.Tanh()

    def forward(self, x, edge_idx, edge_attr):
        hiden = torch.zeros(x[0].shape[0], self.hiden_dim).to(device)
        hiden_arr = []

        for x_item, edge_item, attr_item in zip(x, edge_idx, edge_attr):
            x_item = x_item.to(device)
            edge_item = edge_item.to(device)
            attr_item = attr_item.to(device)

            combined = torch.cat((x_item, hiden), dim=1)

            r = self.sigmoid(
                self.reset_conv(combined, edge_item, attr_item)
            )
            u = self.sigmoid(
                self.update_conv(combined, edge_item, attr_item)
            )
            c = self.tanh(
                self.mem_conv(
                    torch.cat((x_item, r * hiden), dim=1), edge_item, attr_item
                )
            )

            hiden = u * hiden + (1 - u) * c
            hiden_arr.append(hiden)

        return hiden, hiden_arr


class EmoClassifier(nn.Module):
    def __init__(self, num_classes, num_nodes, input_dim, hiden_dim, K, normalization="sym"):
        super().__init__()
        self.num_nodes = num_nodes
        self.encoder = DCGRU(input_dim, 128, K, normalization)
        self.encoder2 = DCGRU(128, 128, K, normalization)
        self.decoder = DCGRU(128, 128, K, normalization)

        self.fc = nn.Linear(128 * 62, 256)
        self.fc2 = nn.Linear(256, num_classes)
        self.dropout = nn.Dropout(0.9)
        self.drp = nn.Dropout(0.9)
        self.relu = nn.ReLU()

    def forward(self, x, edge_idx, edge_attr):
        h1, s = self.encoder(x, edge_idx, edge_attr)
        h2, _ = self.encoder2(s, edge_idx, edge_attr)

        for _ in range(1):
            h1, _ = self.decoder([h2], edge_idx, edge_attr)

        last_out = torch.stack(torch.split(h1, self.num_nodes, dim=0), dim=0)
        last_out = torch.flatten(last_out, 1)

        logits = self.fc2(self.drp(self.fc(self.relu(self.dropout(last_out)))))

        # max-pooling over nodes
        # pool_logits, _ = torch.max(logits, dim=1)  # (batch_size, num_classes)

        return logits

# %%
dataset = SEEDIVDataset("data/content/ns_opt_final_big.zarr", group_shape=(12, 62, 5))
print(len(dataset))
dataset = [dataset[i] for i in tqdm(range(len(dataset)))]

print(len(dataset))
loader = DataLoader(
    dataset,
    batch_size=62,
    shuffle=True,
    num_workers=0
)
# Out:
# 8070
#   0%|          | 0/8070 [00:00<?, ?it/s]
# 8070

# %%
test_dataset = SEEDIVDataset("data/content/ns_opt_final_test_big.zarr", group_shape=(12, 62, 5))
print(len(test_dataset))


import random
arr = list(np.arange(8000))
random.shuffle(arr)
test_dataset = [test_dataset[i] for i in tqdm(range(len(test_dataset)))]

test_loader = DataLoader(
    test_dataset,
    batch_size=62,
    shuffle=False,
    num_workers=0
)
# Out:
# 3930
#   0%|          | 0/3930 [00:00<?, ?it/s]

# %%
dataset = SEEDIVDataset("data/content/final_big.zarr", group_shape=(17, 62, 5))
print(len(dataset))
dataset = [dataset[i] for i in tqdm(range(len(dataset)))]

print(len(dataset))
loader = DataLoader(
    dataset,
    batch_size=62,
    shuffle=True,
    num_workers=0
)
# Out:
# 5535
#   0%|          | 0/5535 [00:00<?, ?it/s]
# 5535

# %%
test_dataset = SEEDIVDataset("data/content/final_test_big.zarr", group_shape=(17, 62, 5))
print(len(test_dataset))


import random
arr = list(np.arange(8000))
random.shuffle(arr)
test_dataset = [test_dataset[i] for i in tqdm(range(len(test_dataset)))]

test_loader = DataLoader(
    test_dataset,
    batch_size=62,
    shuffle=False,
    num_workers=0
)
# Out:
# 2730
#   0%|          | 0/2730 [00:00<?, ?it/s]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def eval_model(model, test_loader, device):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Тестирование"):
            x_batch = [data.x.to(device) for data in batch[0]]
            idx_batch = [data.edge_index.to(device) for data in batch[0]]
            attr_batch = [data.edge_attr.to(device) for data in batch[0]]
            b = [batch[0][0].batch.to(device)] * len(x_batch)
            labels = batch[1].to(torch.long).to(device)

            outputs = model(x_batch, idx_batch, attr_batch, batch[0][0].batch)
            preds = torch.argmax(outputs, dim=1)

            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())

    all_preds = torch.cat(all_preds)
    all_labels = torch.cat(all_labels)

    acc = accuracy_score(all_labels, all_preds)
    print(f"Accuracy: {acc:.4f}")
    print("Classification Report:")
    print(classification_report(all_labels, all_preds))

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import ChebConv, TopKPooling, GCNConv

N_CH = 62


class GCN_LSTM(torch.nn.Module):
    def __init__(self, node_features, seq_len, output_dim):
        super().__init__()
        self.conv1 = ChebConv(
            in_channels=node_features,
            out_channels=node_features,
            K=2,
            normalization="sym",
            bias=True
        )
        self.conv2 = ChebConv(
            in_channels=node_features,
            out_channels=node_features,
            K=2,
            normalization="sym",
            bias=True
        )
        self.conv3 = ChebConv(
            in_channels=node_features,
            out_channels=node_features,
            K=2,
            normalization="sym",
            bias=True
        )
        self.pool_ratio = 0.8
        self.pool1 = TopKPooling(node_features, ratio=self.pool_ratio)
        #self.pool2 = TopKPooling(node_features, ratio=self.pool_ratio)
        #self.new_n_ch = int(np.ceil(np.ceil(N_CH * self.pool_ratio) * self.pool_ratio))
        self.new_n_ch = N_CH#int(np.ceil(N_CH * self.pool_ratio))
        self.lstm1 = nn.LSTM(
            self.new_n_ch * 5,
            128, #64,
            bidirectional=False,
            num_layers=1,
            batch_first=True
        )
        self.lstm2 = nn.LSTM(
            128, #64,
            128, #128,
            bidirectional=False,
            num_layers=1,
            batch_first=True
        )
        self.lstm3 = nn.LSTM(
            128,
            256,
            bidirectional=False,
            num_layers=1,
            batch_first=True
        )

        #self.pool_size = 256

        self.dropout0 = nn.Dropout(0.1)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.3)
        self.dropout3 = nn.Dropout(0.35)
        self.linear1 = nn.Linear(1536, 128)
        #self.linear1 = nn.Linear(seq_len * 256, 256)
        #self.linear1 = nn.Linear(self.pool_size * 256, 256)
        #self.linear2 = nn.Linear(256, 128)
        self.linear3 = nn.Linear(128, 64)
        self.linear4 = nn.Linear(128, output_dim)

    # -> x.shape = N*KxFxT
    def forward(self, x, edge_index, edge_weight):
        x_conv = []
        for t in range(len(x)):
            x_t = self.conv1(x[t], edge_index[t], edge_weight[t])
            x_t = F.leaky_relu(x_t)
            #x_t, edge_index_, edge_weight_, batch_, _, _ = self.pool1(x_t, edge_index, edge_weight, batch)
            x_t = self.conv2(x_t, edge_index[t], edge_weight[t])
            #x_t, edge_index_, edge_weight_, batch_, _, _ = self.pool2(x_t, edge_index_, edge_weight_, batch_)
            #x_t = self.conv3(x_t, edge_index_, edge_weight_, batch_)
            x_conv.append(x_t.unsqueeze(-1))

        # -> x_conv.shape = N*KxFxT
        x_conv = torch.cat(x_conv, -1)
        x_conv = x_conv.reshape(-1, self.new_n_ch, x_conv.shape[1], x_conv.shape[2])
        #x_conv = x_conv.transpose(1, 2).transpose(2, 3).transpose(1, 2)
        x_conv = x_conv.transpose(2, 3).transpose(1, 2)
        #x_conv = x_conv.reshape(x_conv.shape[0], -1, self.new_n_ch)
        x_conv = x_conv.reshape(x_conv.shape[0], x_conv.shape[1], -1)
        #x_conv = self.dropout0(x_conv)

        # -> x_conv.shape = NxF*TxK
        x_lstm, _ = self.lstm1(x_conv)
        x_lstm = self.dropout1(x_lstm)
        #x_lstm, _ = self.lstm2(x_lstm)
        #x_lstm = self.dropout2(x_lstm)
        #x_lstm, _ = self.lstm3(x_lstm)

        #x_lstm = x_lstm.transpose(1, 2)
        #x_lstm = F.adaptive_max_pool1d(x_lstm, output_size=self.pool_size).transpose(1, 2)
        #x_lstm = self.dropout3(x_lstm)

        x_lin = torch.flatten(x_lstm, 1)
        x_lin = F.relu(self.linear1(x_lin))
        x_lin = self.dropout1(x_lin)
        #x_lin = F.relu(self.linear2(x_lin))
        #x_lin = self.dropout3(x_lin)
        #x_lin = F.relu(self.linear3(x_lin))
        x_lin = self.linear4(x_lin)
        return x_lin

# %%
model = EmoClassifier(4, 62, 5, 128, 3).to(device)
# model = GCN_LSTM(5, 12, 4).to(device)
# model = EmBel(4, 62, 5).to(device)
# model = BlendRNNClassifier(5).to(device)
optimizer = optim.AdamW(model.parameters(), lr=0.0005, weight_decay=0.0001)
criterion = nn.CrossEntropyLoss().to(device)


train_losses = []
val_losses = []

num_epochs = 500

for epoch in tqdm(range(num_epochs), desc="Training"):
    model.train()
    train_loss = 0

    train_iter = tqdm(loader, desc=f"[{epoch+1}/{num_epochs}] Training", leave=False)
    for batch in train_iter:
        x_batch = [data.x.to(device) for data in batch[0]]
        idx_batch = [data.edge_index.to(device) for data in batch[0]]
        attr_batch = [data.edge_attr.to(device) for data in batch[0]]
        labels = batch[1].to(torch.long).to(device)

        if len(labels) != 62:
            continue

        b = batch[0][0].batch

        optimizer.zero_grad()
        outputs = model(x_batch, idx_batch, attr_batch)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    avg_train_loss = train_loss / len(loader)
    train_losses.append(avg_train_loss)

    # model.eval()
    val_loss = 0
    # val_iter = tqdm(test_loader, desc=f"[{epoch+1}/{num_epochs}] Validation", leave=False)

    # with torch.no_grad():
    #     for batch in val_iter:
    #         x_batch = [data.x.to(device) for data in batch[0]]
    #         idx_batch = [data.edge_index.to(device) for data in batch[0]]
    #         attr_batch = [data.edge_attr.to(device) for data in batch[0]]
    #         labels = batch[1].to(torch.long).to(device)

    #         outputs = model(x_batch, idx_batch, attr_batch)
    #         loss = criterion(outputs, labels)
    #         val_loss += loss.item()

    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Тестирование"):
            x_batch = [data.x.to(device) for data in batch[0]]
            idx_batch = [data.edge_index.to(device) for data in batch[0]]
            attr_batch = [data.edge_attr.to(device) for data in batch[0]]
            labels = batch[1].to(torch.long).to(device)

            if len(labels) != 62:
                continue

            outputs = model(x_batch, idx_batch, attr_batch)
            preds = torch.argmax(outputs, dim=1)

            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())
            loss = criterion(outputs, labels)
            val_loss += loss.item()

    all_preds = torch.cat(all_preds)
    all_labels = torch.cat(all_labels)

    acc = accuracy_score(all_labels, all_preds)

    avg_val_loss = val_loss / len(test_loader)
    val_losses.append(avg_val_loss)

    print(f"Epoch [{epoch+1}/{num_epochs}] | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}, Accuracy: {acc:.4f}")


    if (epoch) % 10 == 0:
        torch.save({
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
        }, f"emo_classifier{epoch}.pth")
        # np.save("train_losses.npy", train_losses)
        # np.save("test_losses.npy", val_losses)
# Out:
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [1/500] | Train Loss: 1.3791 | Val Loss: 1.3522, Accuracy: 0.2883
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [2/500] | Train Loss: 1.3474 | Val Loss: 1.3274, Accuracy: 0.3500
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [3/500] | Train Loss: 1.3226 | Val Loss: 1.3253, Accuracy: 0.3338
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [4/500] | Train Loss: 1.3070 | Val Loss: 1.3073, Accuracy: 0.3804
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [5/500] | Train Loss: 1.2874 | Val Loss: 1.2992, Accuracy: 0.3707
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [6/500] | Train Loss: 1.2778 | Val Loss: 1.2833, Accuracy: 0.3932
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [7/500] | Train Loss: 1.2610 | Val Loss: 1.2730, Accuracy: 0.4027
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# ...

# %%
import torch

# (12, 62, 5)
# chunk_size = 17
# time_step_size = 3 * fs
# step = 50

train_loss = torch.tensor([
    1.3791, 1.3474, 1.3226, 1.3070, 1.2874,
    1.2778, 1.2610, 1.2453, 1.2277, 1.2106,
    1.1984, 1.1902, 1.1693, 1.1629, 1.1511,
    1.1410, 1.1326, 1.1298, 1.1202, 1.1088,
    1.1048, 1.0950, 1.0845, 1.0776, 1.0670,
    1.0556, 1.0527
])

val_loss = torch.tensor([
    1.3522, 1.3274, 1.3253, 1.3073, 1.2992,
    1.2833, 1.2730, 1.2722, 1.2827, 1.2543,
    1.2842, 1.2826, 1.2648, 1.2772, 1.2586,
    1.2648, 1.2508, 1.2662, 1.2923, 1.2706,
    1.2953, 1.3119, 1.2736, 1.2978, 1.3003,
    1.3063, 1.2751
])

accuracy = torch.tensor([
    0.2883, 0.3500, 0.3338, 0.3804, 0.3707,
    0.3932, 0.4027, 0.4004, 0.3848, 0.4147,
    0.3902, 0.3925, 0.4160, 0.4127, 0.4099,
    0.4081, 0.4306, 0.4104, 0.4235, 0.4232,
    0.3991, 0.4127, 0.4247, 0.4160, 0.4260,
    0.4201, 0.4130
])

# %%
model = EmoClassifier(4, 62, 5, 128, 3).to(device)
# model = GCN_LSTM(5, 12, 4).to(device)
# model = EmBel(4, 62, 5).to(device)
# model = BlendRNNClassifier(5).to(device)
optimizer = optim.AdamW(model.parameters(), lr=0.0005, weight_decay=0.0001)
criterion = nn.CrossEntropyLoss().to(device)


train_losses = []
val_losses = []

num_epochs = 500

for epoch in tqdm(range(num_epochs), desc="Training"):
    model.train()
    train_loss = 0

    train_iter = tqdm(loader, desc=f"[{epoch+1}/{num_epochs}] Training", leave=False)
    for batch in train_iter:
        x_batch = [data.x.to(device) for data in batch[0]]
        idx_batch = [data.edge_index.to(device) for data in batch[0]]
        attr_batch = [data.edge_attr.to(device) for data in batch[0]]
        labels = batch[1].to(torch.long).to(device)

        if len(labels) != 62:
            continue

        b = batch[0][0].batch

        optimizer.zero_grad()
        outputs = model(x_batch, idx_batch, attr_batch)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    avg_train_loss = train_loss / len(loader)
    train_losses.append(avg_train_loss)

    # model.eval()
    val_loss = 0
    # val_iter = tqdm(test_loader, desc=f"[{epoch+1}/{num_epochs}] Validation", leave=False)

    # with torch.no_grad():
    #     for batch in val_iter:
    #         x_batch = [data.x.to(device) for data in batch[0]]
    #         idx_batch = [data.edge_index.to(device) for data in batch[0]]
    #         attr_batch = [data.edge_attr.to(device) for data in batch[0]]
    #         labels = batch[1].to(torch.long).to(device)

    #         outputs = model(x_batch, idx_batch, attr_batch)
    #         loss = criterion(outputs, labels)
    #         val_loss += loss.item()

    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Тестирование"):
            x_batch = [data.x.to(device) for data in batch[0]]
            idx_batch = [data.edge_index.to(device) for data in batch[0]]
            attr_batch = [data.edge_attr.to(device) for data in batch[0]]
            labels = batch[1].to(torch.long).to(device)

            if len(labels) != 62:
                continue

            outputs = model(x_batch, idx_batch, attr_batch)
            preds = torch.argmax(outputs, dim=1)

            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())
            loss = criterion(outputs, labels)
            val_loss += loss.item()

    all_preds = torch.cat(all_preds)
    all_labels = torch.cat(all_labels)

    acc = accuracy_score(all_labels, all_preds)

    avg_val_loss = val_loss / len(test_loader)
    val_losses.append(avg_val_loss)

    print(f"Epoch [{epoch+1}/{num_epochs}] | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}, Accuracy: {acc:.4f}")


    if (epoch) % 10 == 0:
        torch.save({
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
        }, f"emo_classifier{epoch}.pth")
        np.save("train_losses.npy", train_losses)
        np.save("test_losses.npy", val_losses)
# Out:
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [1/500] | Train Loss: 1.3831 | Val Loss: 1.3495, Accuracy: 0.3259
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [2/500] | Train Loss: 1.3514 | Val Loss: 1.3374, Accuracy: 0.3336
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [3/500] | Train Loss: 1.3333 | Val Loss: 1.3254, Accuracy: 0.3607
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [4/500] | Train Loss: 1.3192 | Val Loss: 1.3235, Accuracy: 0.3669
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [5/500] | Train Loss: 1.3051 | Val Loss: 1.3165, Accuracy: 0.3303
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [6/500] | Train Loss: 1.2877 | Val Loss: 1.3081, Accuracy: 0.3926
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [7/500] | Train Loss: 1.2786 | Val Loss: 1.2927, Accuracy: 0.3933
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# ...

# %%
model = EmoClassifier(4, 62, 5, 128, 3).to(device)
# model = GCN_LSTM(5, 12, 4).to(device)
# model = EmBel(4, 62, 5).to(device)
# model = BlendRNNClassifier(5).to(device)
optimizer = optim.AdamW(model.parameters(), lr=0.0005, weight_decay=0.0001)
criterion = nn.CrossEntropyLoss().to(device)


train_losses = []
val_losses = []

num_epochs = 500

for epoch in tqdm(range(num_epochs), desc="Training"):
    model.train()
    train_loss = 0

    train_iter = tqdm(loader, desc=f"[{epoch+1}/{num_epochs}] Training", leave=False)
    for batch in train_iter:
        x_batch = [data.x.to(device) for data in batch[0]]
        idx_batch = [data.edge_index.to(device) for data in batch[0]]
        attr_batch = [data.edge_attr.to(device) for data in batch[0]]
        labels = batch[1].to(torch.long).to(device)

        if len(labels) != 62:
            continue

        b = batch[0][0].batch

        optimizer.zero_grad()
        outputs = model(x_batch, idx_batch, attr_batch)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    avg_train_loss = train_loss / len(loader)
    train_losses.append(avg_train_loss)

    # model.eval()
    val_loss = 0
    # val_iter = tqdm(test_loader, desc=f"[{epoch+1}/{num_epochs}] Validation", leave=False)

    # with torch.no_grad():
    #     for batch in val_iter:
    #         x_batch = [data.x.to(device) for data in batch[0]]
    #         idx_batch = [data.edge_index.to(device) for data in batch[0]]
    #         attr_batch = [data.edge_attr.to(device) for data in batch[0]]
    #         labels = batch[1].to(torch.long).to(device)

    #         outputs = model(x_batch, idx_batch, attr_batch)
    #         loss = criterion(outputs, labels)
    #         val_loss += loss.item()

    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Тестирование"):
            x_batch = [data.x.to(device) for data in batch[0]]
            idx_batch = [data.edge_index.to(device) for data in batch[0]]
            attr_batch = [data.edge_attr.to(device) for data in batch[0]]
            labels = batch[1].to(torch.long).to(device)

            if len(labels) != 62:
                continue

            outputs = model(x_batch, idx_batch, attr_batch)
            preds = torch.argmax(outputs, dim=1)

            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())
            loss = criterion(outputs, labels)
            val_loss += loss.item()

    all_preds = torch.cat(all_preds)
    all_labels = torch.cat(all_labels)

    acc = accuracy_score(all_labels, all_preds)

    avg_val_loss = val_loss / len(test_loader)
    val_losses.append(avg_val_loss)

    print(f"Epoch [{epoch+1}/{num_epochs}] | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}, Accuracy: {acc:.4f}")


    if (epoch) % 10 == 0:
        torch.save({
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
        }, f"emo_classifier{epoch}.pth")
        np.save("train_losses_2layers.npy", train_losses)
        np.save("test_losses_2layers.npy", val_losses)
# Out:
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [1/500] | Train Loss: 1.3866 | Val Loss: 1.3510, Accuracy: 0.2753
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [2/500] | Train Loss: 1.3501 | Val Loss: 1.3444, Accuracy: 0.3259
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [3/500] | Train Loss: 1.3434 | Val Loss: 1.3341, Accuracy: 0.3328
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [4/500] | Train Loss: 1.3254 | Val Loss: 1.3312, Accuracy: 0.2815
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [5/500] | Train Loss: 1.3196 | Val Loss: 1.3160, Accuracy: 0.3402
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [6/500] | Train Loss: 1.3102 | Val Loss: 1.3305, Accuracy: 0.3460
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch [7/500] | Train Loss: 1.3001 | Val Loss: 1.3224, Accuracy: 0.3365
# ...
# Тестирование:   0%|          | 0/45 [00:00<?, ?it/s]
# ...

# %%
np.save("train_losses_2layers.npy", train_losses)
np.save("test_losses_2layers.npy", val_losses)

# %%
model = EmoClassifier(4, 62, 5, 128, 3).to(device)
# model = GCN_LSTM(5, 12, 4).to(device)
# model = EmBel(4, 62, 5).to(device)
# model = BlendRNNClassifier(5).to(device)
optimizer = optim.AdamW(model.parameters(), lr=0.0005, weight_decay=0.0001)
criterion = nn.CrossEntropyLoss().to(device)


train_losses = []
val_losses = []

num_epochs = 500

for epoch in tqdm(range(num_epochs), desc="Training"):
    model.train()
    train_loss = 0

    train_iter = tqdm(loader, desc=f"[{epoch+1}/{num_epochs}] Training", leave=False)
    for batch in train_iter:
        x_batch = [data.x.to(device) for data in batch[0]]
        idx_batch = [data.edge_index.to(device) for data in batch[0]]
        attr_batch = [data.edge_attr.to(device) for data in batch[0]]
        labels = batch[1].to(torch.long).to(device)

        if len(labels) != 62:
            continue

        b = batch[0][0].batch

        optimizer.zero_grad()
        outputs = model(x_batch, idx_batch, attr_batch)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    avg_train_loss = train_loss / len(loader)
    train_losses.append(avg_train_loss)

    # model.eval()
    val_loss = 0
    # val_iter = tqdm(test_loader, desc=f"[{epoch+1}/{num_epochs}] Validation", leave=False)

    # with torch.no_grad():
    #     for batch in val_iter:
    #         x_batch = [data.x.to(device) for data in batch[0]]
    #         idx_batch = [data.edge_index.to(device) for data in batch[0]]
    #         attr_batch = [data.edge_attr.to(device) for data in batch[0]]
    #         labels = batch[1].to(torch.long).to(device)

    #         outputs = model(x_batch, idx_batch, attr_batch)
    #         loss = criterion(outputs, labels)
    #         val_loss += loss.item()

    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Тестирование"):
            x_batch = [data.x.to(device) for data in batch[0]]
            idx_batch = [data.edge_index.to(device) for data in batch[0]]
            attr_batch = [data.edge_attr.to(device) for data in batch[0]]
            labels = batch[1].to(torch.long).to(device)

            if len(labels) != 62:
                continue

            outputs = model(x_batch, idx_batch, attr_batch)
            preds = torch.argmax(outputs, dim=1)

            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())
            loss = criterion(outputs, labels)
            val_loss += loss.item()

    all_preds = torch.cat(all_preds)
    all_labels = torch.cat(all_labels)

    acc = accuracy_score(all_labels, all_preds)

    avg_val_loss = val_loss / len(test_loader)
    val_losses.append(avg_val_loss)

    print(f"Epoch [{epoch+1}/{num_epochs}] | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}, Accuracy: {acc:.4f}")


    if (epoch) % 10 == 0:
        torch.save({
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
        }, f"emo_classifier{epoch}.pth")
        np.save("train_losses2layers222.npy", train_losses)
        np.save("test_losses2layers2222.npy", val_losses)
# Out:
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [1/500] | Train Loss: 1.3887 | Val Loss: 1.3587, Accuracy: 0.3041
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [2/500] | Train Loss: 1.3537 | Val Loss: 1.3402, Accuracy: 0.3200
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [3/500] | Train Loss: 1.3361 | Val Loss: 1.3310, Accuracy: 0.3269
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [4/500] | Train Loss: 1.3255 | Val Loss: 1.3289, Accuracy: 0.3290
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [5/500] | Train Loss: 1.3126 | Val Loss: 1.3110, Accuracy: 0.3607
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [6/500] | Train Loss: 1.3023 | Val Loss: 1.3254, Accuracy: 0.3500
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [7/500] | Train Loss: 1.2900 | Val Loss: 1.3024, Accuracy: 0.3720
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# ...

# %%
np.save("train_losses2layers222.npy", train_losses)
np.save("test_losses2layers2222.npy", val_losses)

# %%
gru = nn.GRU(5, 128).to(device)
model = nn.Sequential(
    nn.Linear(128, 128),
    nn.Dropout(0.3),
    nn.Linear(128, 4)
).to(device)
# model = GCN_LSTM(5, 12, 4).to(device)
# model = EmBel(4, 62, 5).to(device)
# model = BlendRNNClassifier(5).to(device)
optimizer = optim.AdamW(model.parameters(), lr=0.0005, weight_decay=0.0001)
criterion = nn.CrossEntropyLoss().to(device)


train_losses = []
val_losses = []
accuracy = []

num_epochs = 500

for epoch in tqdm(range(num_epochs), desc="Training"):
    model.train()
    train_loss = 0

    train_iter = tqdm(loader, desc=f"[{epoch+1}/{num_epochs}] Training", leave=False)
    for batch in train_iter:
        x_batch = torch.tensor(np.array([(data.x) for data in batch[0]]))
        labels = batch[1].to(torch.long).to(device)

        if len(labels) != 62:
            continue

        b = batch[0][0].batch

        all_averaged_blocks = []
        for tensor in x_batch:
            blocks = torch.split(tensor, 62, dim=0)
            averaged = [b.mean(dim=0) for b in blocks]
            all_averaged_blocks.append(torch.stack(averaged, dim=0))

        gru_inputs = torch.stack(all_averaged_blocks, dim=0).to(device)
        # gru_inputs = all_blocks_tensor.permute(1, 0, 2).to(device)


        optimizer.zero_grad()

        inp = gru(gru_inputs)[1][-1]

        outputs = model(gru(gru_inputs)[1][-1])

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    avg_train_loss = train_loss / len(loader)
    train_losses.append(avg_train_loss)

    # model.eval()
    val_loss = 0
    # val_iter = tqdm(test_loader, desc=f"[{epoch+1}/{num_epochs}] Validation", leave=False)

    # with torch.no_grad():
    #     for batch in val_iter:
    #         x_batch = [data.x.to(device) for data in batch[0]]
    #         idx_batch = [data.edge_index.to(device) for data in batch[0]]
    #         attr_batch = [data.edge_attr.to(device) for data in batch[0]]
    #         labels = batch[1].to(torch.long).to(device)

    #         outputs = model(x_batch, idx_batch, attr_batch)
    #         loss = criterion(outputs, labels)
    #         val_loss += loss.item()

    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Тестирование"):
            x_batch = torch.tensor(np.array([data.x for data in batch[0]]))
            labels = batch[1].to(torch.long).to(device)

            if len(labels) != 62:
                continue

            all_averaged_blocks = []
            for tensor in x_batch:
                blocks = torch.split(tensor, 62, dim=0)
                averaged = [b.mean(dim=0) for b in blocks]
                all_averaged_blocks.append(torch.stack(averaged, dim=0))

            gru_inputs = torch.stack(all_averaged_blocks, dim=0).to(device)
            # gru_inputs = all_blocks_tensor.permute(1, 0, 2).to(device)

            outputs = model(gru(gru_inputs)[1][-1])
            preds = torch.argmax(outputs, dim=1)

            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())
            loss = criterion(outputs, labels)
            val_loss += loss.item()

    all_preds = torch.cat(all_preds)
    all_labels = torch.cat(all_labels)

    acc = accuracy_score(all_labels, all_preds)

    avg_val_loss = val_loss / len(test_loader)
    val_losses.append(avg_val_loss)
    accuracy.append(acc)

    print(f"Epoch [{epoch+1}/{num_epochs}] | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}, Accuracy: {acc:.4f}")


    if (epoch) % 10 == 0:
        torch.save({
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
        }, f"emo_classifier{epoch}.pth")
        np.save("train_losses_GRU.npy", train_losses)
        np.save("test_losses_GRU.npy", val_losses)
        np.save("acc.npy", accuracy)
# Out:
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [1/500] | Train Loss: 1.3645 | Val Loss: 1.3643, Accuracy: 0.3139
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [2/500] | Train Loss: 1.3573 | Val Loss: 1.3613, Accuracy: 0.3018
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [3/500] | Train Loss: 1.3540 | Val Loss: 1.3626, Accuracy: 0.2934
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [4/500] | Train Loss: 1.3525 | Val Loss: 1.3600, Accuracy: 0.2888
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [5/500] | Train Loss: 1.3514 | Val Loss: 1.3563, Accuracy: 0.2883
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [6/500] | Train Loss: 1.3499 | Val Loss: 1.3605, Accuracy: 0.2862
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch [7/500] | Train Loss: 1.3499 | Val Loss: 1.3616, Accuracy: 0.2819
# ...
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# ...

# %%
np.save("train_losses_GRU.npy", train_losses)
np.save("test_losses_GRU.npy", val_losses)
np.save("acc_GRU.npy", accuracy)

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train vs Validation Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def test_model(model, test_loader, device):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Тестирование"):
            x_batch = [data.x.to(device) for data in batch[0]]
            idx_batch = [data.edge_index.to(device) for data in batch[0]]
            attr_batch = [data.edge_attr.to(device) for data in batch[0]]
            labels = batch[1].to(torch.long).to(device)

            outputs = model(x_batch, idx_batch, attr_batch)
            preds = torch.argmax(outputs, dim=1)

            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())

    all_preds = torch.cat(all_preds)
    all_labels = torch.cat(all_labels)

    acc = accuracy_score(all_labels, all_preds)
    print(f"Accuracy: {acc:.4f}")
    print("Classification Report:")
    print(classification_report(all_labels, all_preds))

    # Confusion matrix
    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=range(4), yticklabels=range(4))
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confusion Matrix")
    plt.show()

# %%
test_model(model, test_loader, device)
plt.savefig("confusion_matix_for_big_2layers222.png")
# Out:
# Тестирование:   0%|          | 0/64 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-273858387c00> in <cell line: 0>()
# ----> 1 test_model(model, test_loader, device)
#       2 plt.savefig("confusion_matix_for_big_2layers222.png")
#
# <ipython-input-26-fb6c19b7dfdb> in test_model(model, test_loader, device)
#      15             labels = batch[1].to(torch.long).to(device)
#      16
# ---> 17             outputs = model(x_batch, idx_batch, attr_batch)
#      18             preds = torch.argmax(outputs, dim=1)
#      19
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
# ...
